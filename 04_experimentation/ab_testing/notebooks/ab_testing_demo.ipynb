# %% [markdown]
# # A/B Testing Demo
#
# This notebook demonstrates a simple experimentation workflow for a junior ML portfolio.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().resolve().parent / 'src'))

from ab_test import generate_data, run_ab_test

df = generate_data(seed=42, mean_a=10.0, mean_b=10.6)
result = run_ab_test(df)
result
# Out:
# {'mean_a': 9.942216898008107,
#  'mean_b': 10.43724329050121,
#  'abs_lift': 0.4950263924931022,
#  'relative_lift': 0.049790343297809084,
#  't_statistic': 5.523740225816608,
#  'p_value': 3.752446936895437e-08,
#  'ci_lower': np.float64(0.3192718596568099),
#  'ci_upper': np.float64(0.6707809253293946),
#  'significant': True,
#  'control_group': 'A',
#  'treatment_group': 'B',
#  'n_control': 1000,
#  'n_treatment': 1000}
